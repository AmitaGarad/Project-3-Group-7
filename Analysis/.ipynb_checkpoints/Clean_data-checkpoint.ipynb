# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
df = pd.read_json('../Resources/influencer_data.jsonl', lines=True)
df
# Out:
#                    Name  Age     Sex Country of Origin State or Province  \
# 0         Andre Mcclain   23    male               USA    South Carolina
# 1        Gregory Joseph   19    male               USA              Iowa
# 2          William Wall   23    male               USA            Oregon
# 3      Virginia Chapman   24  female               USA      Pennsylvania
# 4        Deborah Potter   33  female            Canada            Quebec
# ...                 ...  ...     ...               ...               ...
# 32885     Linda Mendoza   30  female            Canada           Ontario
# 32886  Meredith Jenkins   20  female               USA              Ohio
# 32887       Karen Garza   35  female               USA         Tennessee
# 32888     Sheila Harris   32  female               USA          New York
# 32889    Kenneth Burton   25    male            Canada           Ontario
#
#       Education Level MBTI Personality     Lifestyle  \
# ...

# %%
df_csv = pd.read_csv('../Resources/DEC_YOUTUBE_INFLUENCER_RAW.csv')
df_csv
# Out:
#       s.no            Youtube channel               youtuber name  \
# 0        1                    tseries                    T-Series
# 1        2                   setindia                   SET India
# 2        3                  checkgate  Cocomelon - Nursery Rhymes
# 3        4                    MrBeast                     MrBeast
# 4        5                  PewDiePie                   PewDiePie
# ...    ...                        ...                         ...
# 998    999              ClassicMrBean             Classic Mr Bean
# 999   1000         Anupam Movie Songs          Anupam Movie Songs
# 1000   970                 AnandAudio                 Anand Audio
# 1001   971                   Wylsacom                    Wylsacom
# 1002   986  Eagle Home Entertainments   Eagle Home Entertainments
#
#                   Category Followers        Country Views (Avg.) Likes (Avg.)  \
# 0            Music & Dance    229.5M          India       103.8K         2.8K
# ...

# %%
renamed_df = df_csv.rename(columns={"Youtube channel":"Youtube_channel", "youtuber name":"Youtuber_name","Views (Avg.)":"Average_view",
    "Likes (Avg.)":"Average_likes","Comments (Avg.)":"Average_comments","Category-2":"Sub-category"})
renamed_df.head()
# Out:
#    s.no Youtube_channel               Youtuber_name       Category Followers  \
# 0     1         tseries                    T-Series  Music & Dance    229.5M
# 1     2        setindia                   SET India            NaN    147.2M
# 2     3       checkgate  Cocomelon - Nursery Rhymes      Education    146.6M
# 3     4         MrBeast                     MrBeast    Video games      117M
# 4     5       PewDiePie                   PewDiePie      Animation    111.6M
#
#          Country Average_view Average_likes Average_comments Sub-category  \
# 0          India       103.8K          2.8K              158          NaN
# 1          India            0             0                0          NaN
# 2            NaN         9.5M         48.3K                0          NaN
# 3  United States        68.5M          2.9M            99.9K        Humor
# 4  United States         1.4M        110.7K             7.8K          NaN
#
#          Date  Unnamed: 11
# 0   12/8/2022          NaN
# ...

# %%
cleaned_Dec = renamed_df.fillna({"Category": 'Others',
                                      "Country": 'Unknown',
                                      "Sub-category": 'Others'})
cleaned_Dec.head()
# Out:
#    s.no Youtube_channel               Youtuber_name       Category Followers  \
# 0     1         tseries                    T-Series  Music & Dance    229.5M
# 1     2        setindia                   SET India         Others    147.2M
# 2     3       checkgate  Cocomelon - Nursery Rhymes      Education    146.6M
# 3     4         MrBeast                     MrBeast    Video games      117M
# 4     5       PewDiePie                   PewDiePie      Animation    111.6M
#
#          Country Average_view Average_likes Average_comments Sub-category  \
# 0          India       103.8K          2.8K              158       Others
# 1          India            0             0                0       Others
# 2        Unknown         9.5M         48.3K                0       Others
# 3  United States        68.5M          2.9M            99.9K        Humor
# 4  United States         1.4M        110.7K             7.8K       Others
#
#          Date  Unnamed: 11
# 0   12/8/2022          NaN
# ...

# %%
cleaned_Dec.drop(["Unnamed: 11"],inplace=True)
cleaned_Dec.head()
#df.drop(['column1', 'column2'], axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 cleaned_Dec.drop(["Unnamed: 11"],inplace=True)
#       2 cleaned_Dec.head()
#
# File c:\Anaconda\envs\dev\lib\site-packages\pandas\core\frame.py:5258, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5110 def drop(
#    5111     self,
#    5112     labels: IndexLabel = None,
#    (...)
#    5119     errors: IgnoreRaise = "raise",
#    5120 ) -> DataFrame | None:
#    5121     """
#    5122     Drop specified labels from rows or columns.
#    5123
#    (...)
#    5256             weight  1.0     0.8
#    5257     """
# -> 5258     return super().drop(
#    5259         labels=labels,
#    5260         axis=axis,
#    5261         index=index,
#    5262         columns=columns,
#    5263         level=level,
#    5264         inplace=inplace,
# ...
