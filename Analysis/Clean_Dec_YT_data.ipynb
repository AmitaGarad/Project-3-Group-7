# %%
#importing libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
#importing Ai Influencer json file
df = pd.read_json('../Resources/influencer_data.jsonl', lines=True)
df
# Out:
#                    Name  Age     Sex Country of Origin State or Province  \
# 0         Andre Mcclain   23    male               USA    South Carolina
# 1        Gregory Joseph   19    male               USA              Iowa
# 2          William Wall   23    male               USA            Oregon
# 3      Virginia Chapman   24  female               USA      Pennsylvania
# 4        Deborah Potter   33  female            Canada            Quebec
# ...                 ...  ...     ...               ...               ...
# 32885     Linda Mendoza   30  female            Canada           Ontario
# 32886  Meredith Jenkins   20  female               USA              Ohio
# 32887       Karen Garza   35  female               USA         Tennessee
# 32888     Sheila Harris   32  female               USA          New York
# 32889    Kenneth Burton   25    male            Canada           Ontario
#
#       Education Level MBTI Personality     Lifestyle  \
# ...

# %%
#importing December Youtube data
df_csv = pd.read_csv('../Resources/DEC_YOUTUBE_INFLUENCER_RAW.csv')
df_csv
# Out:
#       s.no            Youtube channel               youtuber name  \
# 0        1                    tseries                    T-Series
# 1        2                   setindia                   SET India
# 2        3                  checkgate  Cocomelon - Nursery Rhymes
# 3        4                    MrBeast                     MrBeast
# 4        5                  PewDiePie                   PewDiePie
# ...    ...                        ...                         ...
# 998    999              ClassicMrBean             Classic Mr Bean
# 999   1000         Anupam Movie Songs          Anupam Movie Songs
# 1000   970                 AnandAudio                 Anand Audio
# 1001   971                   Wylsacom                    Wylsacom
# 1002   986  Eagle Home Entertainments   Eagle Home Entertainments
#
#                   Category Followers        Country Views (Avg.) Likes (Avg.)  \
# 0            Music & Dance    229.5M          India       103.8K         2.8K
# ...

# %%
#looking for dupliates
duplicate_values = df_csv['Youtube channel'].duplicated()
print(duplicate_values)
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 998     False
# 999     False
# 1000     True
# 1001     True
# 1002     True
# Name: Youtube channel, Length: 1003, dtype: bool

# %%
#dropping duplicates
Dec_df=df_csv.drop_duplicates(subset=['Youtube channel'], keep='first')
Dec_df
# Out:
#      s.no     Youtube channel                        youtuber name  \
# 0       1             tseries                             T-Series
# 1       2            setindia                            SET India
# 2       3           checkgate           Cocomelon - Nursery Rhymes
# 3       4             MrBeast                              MrBeast
# 4       5           PewDiePie                            PewDiePie
# ..    ...                 ...                                  ...
# 995   996    SULE PRODUCTIONS                     SULE PRODUCTIONS
# 996   997       Dynamo Gaming                        Dynamo Gaming
# 997   998     one_Iraqi_Diary  يوميات واحد عراقي | One Iraqi Diary
# 998   999       ClassicMrBean                      Classic Mr Bean
# 999  1000  Anupam Movie Songs                   Anupam Movie Songs
#
#           Category Followers        Country Views (Avg.) Likes (Avg.)  \
# 0    Music & Dance    229.5M          India       103.8K         2.8K
# ...

# %%
#updating column names
renamed_df = Dec_df.rename(columns={"Youtube channel":"Youtube_channel", "youtuber name":"Youtuber_name",
                                    "Followers":"Subscribers","Views (Avg.)":"Average_view",
                                    "Likes (Avg.)":"Average_likes","Comments (Avg.)":"Average_comments",
                                    "Category-2":"Sub-category"})
renamed_df.head()
# Out:
#    s.no Youtube_channel               Youtuber_name       Category  \
# 0     1         tseries                    T-Series  Music & Dance
# 1     2        setindia                   SET India            NaN
# 2     3       checkgate  Cocomelon - Nursery Rhymes      Education
# 3     4         MrBeast                     MrBeast    Video games
# 4     5       PewDiePie                   PewDiePie      Animation
#
#   Subscribers        Country Average_view Average_likes Average_comments  \
# 0      229.5M          India       103.8K          2.8K              158
# 1      147.2M          India            0             0                0
# 2      146.6M            NaN         9.5M         48.3K                0
# 3        117M  United States        68.5M          2.9M            99.9K
# 4      111.6M  United States         1.4M        110.7K             7.8K
#
#   Sub-category        Date
# 0          NaN   12/8/2022
# 1          NaN  12/27/2022
# 2          NaN  12/23/2022
# ...

# %%
#replacing blank values
cleaned_Dec = renamed_df.fillna({"Category": 'Others',
                                      "Country": 'Unknown',
                                      "Sub-category": 'Others'})
cleaned_Dec.head()
# Out:
#    s.no Youtube_channel               Youtuber_name       Category  \
# 0     1         tseries                    T-Series  Music & Dance
# 1     2        setindia                   SET India         Others
# 2     3       checkgate  Cocomelon - Nursery Rhymes      Education
# 3     4         MrBeast                     MrBeast    Video games
# 4     5       PewDiePie                   PewDiePie      Animation
#
#   Subscribers        Country Average_view Average_likes Average_comments  \
# 0      229.5M          India       103.8K          2.8K              158
# 1      147.2M          India            0             0                0
# 2      146.6M        Unknown         9.5M         48.3K                0
# 3        117M  United States        68.5M          2.9M            99.9K
# 4      111.6M  United States         1.4M        110.7K             7.8K
#
#   Sub-category        Date
# 0       Others   12/8/2022
# 1       Others  12/27/2022
# 2       Others  12/23/2022
# ...

# %%
#dropping the number column
cleaned_Dec.drop(columns=['s.no'])
# Out:
#         Youtube_channel                        Youtuber_name       Category  \
# 0               tseries                             T-Series  Music & Dance
# 1              setindia                            SET India         Others
# 2             checkgate           Cocomelon - Nursery Rhymes      Education
# 3               MrBeast                              MrBeast    Video games
# 4             PewDiePie                            PewDiePie      Animation
# ..                  ...                                  ...            ...
# 995    SULE PRODUCTIONS                     SULE PRODUCTIONS         Others
# 996       Dynamo Gaming                        Dynamo Gaming         Others
# 997     one_Iraqi_Diary  يوميات واحد عراقي | One Iraqi Diary         Others
# 998       ClassicMrBean                      Classic Mr Bean         Others
# 999  Anupam Movie Songs                   Anupam Movie Songs  Music & Dance
#
# ...

# %%
filtered_df = cleaned_Dec[cleaned_Dec['Country'] != 'Unknown']
filtered_df
# Out:
#      s.no     Youtube_channel                        Youtuber_name  \
# 0       1             tseries                             T-Series
# 1       2            setindia                            SET India
# 3       4             MrBeast                              MrBeast
# 4       5           PewDiePie                            PewDiePie
# 7       8        WWEFanNation                                  WWE
# ..    ...                 ...                                  ...
# 995   996    SULE PRODUCTIONS                     SULE PRODUCTIONS
# 996   997       Dynamo Gaming                        Dynamo Gaming
# 997   998     one_Iraqi_Diary  يوميات واحد عراقي | One Iraqi Diary
# 998   999       ClassicMrBean                      Classic Mr Bean
# 999  1000  Anupam Movie Songs                   Anupam Movie Songs
#
#           Category Subscribers        Country Average_view Average_likes  \
# 0    Music & Dance      229.5M          India       103.8K          2.8K
# ...

# %%
# to save file as csv to Analysis file
#cleaned_Dec.to_csv("../Analysis/Dec_Youtube.csv", encoding='utf8', index=False)
filtered_df.to_csv("../Resources/Dec_clean_data.csv", index=False, header=True)
